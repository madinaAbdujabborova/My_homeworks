# %% [markdown]
# # Asthma kasalligi bo'yicha kasallanganlar dataseti

# %% [markdown]
# ### Pandasni import qilib chaqirib olish va pd.read_csv funksiyasidan foydalanib kerakli bo'lgan csv faylni ochib olish. Bu funksiya data frame qaytaradi!

# %%
import pandas as pd

df = pd.read_csv('asthma_disease_data.csv')
df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          5034   63       0          1               0  15.848744        0
# 1          5035   26       1          2               2  22.757042        0
# 2          5036   57       0          2               1  18.395396        0
# 3          5037   40       1          2               1  38.515278        0
# 4          5038   61       0          0               3  19.283802        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2387       7421   43       1          0               2  29.059613        0
# 2388       7422   18       1          0               1  20.740850        0
# 2389       7423   54       0          3               2  37.079560        0
# 2390       7424   46       1          0               2  23.444712        0
# 2391       7425   26       1          0               0  28.123021        1
#
# ...

# %% [markdown]
# Patient ID: from 5034 to 7425, Bemorlarni ID si
# Age: from 5 to 80 years
# Gender: 0 - Male, 1 - Female
# EthnicityL: 0: Caucasian
#             1: African American
#             2: Asian
#             3: Other
# Education level: 0: None
#                  1: High School
#                  2: Bachelor's
#                  3: Higher
# BMI: Body mass index. from 15 to 40 (18.5 to 24.9 - healthy, 25.0 to 29.9 - overweight, 30.0 or higher - obese)
# Smoking: 1 - Yes, 0 - No
# PhysicalActivity: Weekly physical activity in hours, ranging from 0 to 10.
# DietQuality: Diet quality score, ranging from 0 to 10.
# SleepQuality: Sleep quality score, ranging from 4 to 10.
#
# I worked with this indicators!

# %% [markdown]
# ### df.head() funksiyasi ichiga qiymat berilmagan taqdirda faqat jadvalning dastlabki 5 ta qatorini chiqaradi. Agar ichiga raqam berilsa osha son miqdoricha qatorlarni chiqaradi.

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       5034   63       0          1               0  15.848744        0
# 1       5035   26       1          2               2  22.757042        0
# 2       5036   57       0          2               1  18.395396        0
# 3       5037   40       1          2               1  38.515278        0
# 4       5038   61       0          0               3  19.283802        0
#
#    PhysicalActivity  DietQuality  SleepQuality  ...  LungFunctionFEV1  \
# 0          0.894448     5.488696      8.701003  ...          1.369051
# 1          5.897329     6.341014      5.153966  ...          2.197767
# 2          6.739367     9.196237      6.840647  ...          1.698011
# 3          1.404503     5.826532      4.253036  ...          3.032037
# 4          4.604493     3.127048      9.625799  ...          3.470589
#
#    LungFunctionFVC  Wheezing  ShortnessOfBreath  ChestTightness  Coughing  \
# ...

# %% [markdown]
# ### df.info() - methodi dT frame haqida ma'lumot beradi. Asosiy ma'lumotlar Biror qator null mi null emasmi shuni korib olish mumkin. umumiy nechta column nechta qator borligini va har bir columnlarning data typeni bilib olishimiz mumkin.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PatientID               2392 non-null   int64
#  1   Age                     2392 non-null   int64
#  2   Gender                  2392 non-null   int64
#  3   Ethnicity               2392 non-null   int64
#  4   EducationLevel          2392 non-null   int64
#  5   BMI                     2392 non-null   float64
#  6   Smoking                 2392 non-null   int64
#  7   PhysicalActivity        2392 non-null   float64
#  8   DietQuality             2392 non-null   float64
#  9   SleepQuality            2392 non-null   float64
#  10  PollutionExposure       2392 non-null   float64
#  11  PollenExposure          2392 non-null   float64
#  12  DustExposure            2392 non-null   float64
#  13  PetAllergy              2392 non-null   int64
# ...

# %% [markdown]
# ### Pandasda 2 ta katta obyekt bor: 1 - Data frame, 2 - Series! Series bu biz data frame dan cma'lum bir columnni ajratib olganimizda hosil bo'ladi. Bunda bitta o'zgaruvchi ochilib age ustuni shu o'zgaruvchiga tenglanyapti typpe: series

# %%
age = df['Age']
type(age)
age
# Out:
# 0       63
# 1       26
# 2       57
# 3       40
# 4       61
#         ..
# 2387    43
# 2388    18
# 2389    54
# 2390    46
# 2391    26
# Name: Age, Length: 2392, dtype: int64

# %% [markdown]
# ### Bundan tashqqari ustunni nuqta bilan ham ajratib olish mumkin. lekin bu tavsiya etilmaydi chunki chalg'itadi!

# %%
age = df.Age
age
# Out:
# 0       63
# 1       26
# 2       57
# 3       40
# 4       61
#         ..
# 2387    43
# 2388    18
# 2389    54
# 2390    46
# 2391    26
# Name: Age, Length: 2392, dtype: int64

# %% [markdown]
# ### Biz bundan tashqari ustunlar ustida amallar qilsak bo'ladi (<, >, <=, >=, ==, !=). Bu amallar bizga boolean(True or False) qaytaradi.

# %%
age > 30
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 2387     True
# 2388    False
# 2389     True
# 2390     True
# 2391    False
# Name: Age, Length: 2392, dtype: bool

# %% [markdown]
# ### Quyidagi amal faqat 30 yoshdan yuqorilarni olib beradi. Type: data frame

# %%
df[age > 30]
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          5034   63       0          1               0  15.848744        0
# 2          5036   57       0          2               1  18.395396        0
# 3          5037   40       1          2               1  38.515278        0
# 4          5038   61       0          0               3  19.283802        0
# 6          5040   45       1          1               1  30.245954        1
# ...         ...  ...     ...        ...             ...        ...      ...
# 2383       7417   62       1          0               2  20.033593        0
# 2384       7418   31       0          0               2  31.821008        1
# 2387       7421   43       1          0               2  29.059613        0
# 2389       7423   54       0          3               2  37.079560        0
# 2390       7424   46       1          0               2  23.444712        0
#
# ...

# %% [markdown]
# ### Quyidagi holat Etnik jihatdan faqat Osiyoda uchraydigan bemorlarni chiqarib beradi!

# %%
df[df['Ethnicity'] == 2]
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 1          5035   26       1          2               2  22.757042        0
# 2          5036   57       0          2               1  18.395396        0
# 3          5037   40       1          2               1  38.515278        0
# 5          5039   21       0          2               0  21.812975        0
# 20         5054   40       1          2               1  23.588420        1
# ...         ...  ...     ...        ...             ...        ...      ...
# 2344       7378   26       1          2               2  17.141151        0
# 2346       7380   37       1          2               1  39.335351        0
# 2356       7390    6       0          2               1  36.501742        0
# 2362       7396   56       1          2               2  38.132535        0
# 2366       7400   35       0          2               0  22.154735        0
#
# ...

# %% [markdown]
# ### df.shape - atribute hisoblanib data frameda nechta qator va nechta ustun borligini tuplega solib qaytaradi.

# %%
shape = df.shape
shape
# Out:
# (2392, 29)

# %% [markdown]
# ### df.describe() - method hisoblanib data frameni umumiy holda tasvirlaydi. Bunda min, max, std, count, quartile(25%, 50%, 75%) bo'ladi

# %%
df.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2392.000000  2392.000000  2392.000000  2392.000000     2392.000000
# mean   6229.500000    42.137960     0.493311     0.669732        1.307274
# std     690.655244    21.606655     0.500060     0.986120        0.898242
# min    5034.000000     5.000000     0.000000     0.000000        0.000000
# 25%    5631.750000    23.000000     0.000000     0.000000        1.000000
# 50%    6229.500000    42.000000     0.000000     0.000000        1.000000
# 75%    6827.250000    61.000000     1.000000     1.000000        2.000000
# max    7425.000000    79.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoking  PhysicalActivity  DietQuality  SleepQuality  \
# count  2392.000000  2392.000000       2392.000000  2392.000000   2392.000000
# mean     27.244877     0.141722          5.051786     5.022867      7.019012
# ...

# %% [markdown]
# ### df.values - atribute hisoblanib data frame ichidagi hamma qatorlarni list ichida list qilib solib beradi

# %%
df.values
# Out:
# array([[5034, 63, 0, ..., 1, 0, 'Dr_Confid'],
#        [5035, 26, 1, ..., 1, 0, 'Dr_Confid'],
#        [5036, 57, 0, ..., 1, 0, 'Dr_Confid'],
#        ...,
#        [7423, 54, 0, ..., 1, 1, 'Dr_Confid'],
#        [7424, 46, 1, ..., 1, 0, 'Dr_Confid'],
#        [7425, 26, 1, ..., 0, 0, 'Dr_Confid']], dtype=object)

# %% [markdown]
# ### df.columns columns nomlarini qaytaradi. df.columns.tolist esa column nomlarini listga solib beradi

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'PollutionExposure', 'PollenExposure', 'DustExposure', 'PetAllergy',
#        'FamilyHistoryAsthma', 'HistoryOfAllergies', 'Eczema', 'HayFever',
#        'GastroesophagealReflux', 'LungFunctionFEV1', 'LungFunctionFVC',
#        'Wheezing', 'ShortnessOfBreath', 'ChestTightness', 'Coughing',
#        'NighttimeSymptoms', 'ExerciseInduced', 'Diagnosis', 'DoctorInCharge'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['PatientID',
#  'Age',
#  'Gender',
#  'Ethnicity',
#  'EducationLevel',
#  'BMI',
#  'Smoking',
#  'PhysicalActivity',
#  'DietQuality',
#  'SleepQuality',
#  'PollutionExposure',
#  'PollenExposure',
#  'DustExposure',
#  'PetAllergy',
#  'FamilyHistoryAsthma',
#  'HistoryOfAllergies',
#  'Eczema',
#  'HayFever',
#  'GastroesophagealReflux',
#  'LungFunctionFEV1',
#  'LungFunctionFVC',
#  'Wheezing',
#  'ShortnessOfBreath',
#  'ChestTightness',
#  'Coughing',
#  'NighttimeSymptoms',
#  'ExerciseInduced',
#  'Diagnosis',
#  'DoctorInCharge']

# %% [markdown]
# ### Sorting - sortlab beruvchi methodlari ham bor

# %%
df.sort_values("Age")
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 703        5737    5       0          0               0  30.163020        0
# 2211       7245    5       0          0               1  38.155312        1
# 2207       7241    5       1          0               2  37.839054        0
# 814        5848    5       0          0               1  17.572297        0
# 2081       7115    5       0          1               3  23.508565        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 68         5102   79       0          0               3  17.786832        0
# 1984       7018   79       1          3               0  17.867079        0
# 1777       6811   79       0          0               2  28.439224        1
# 746        5780   79       1          0               1  32.724673        0
# 1641       6675   79       0          0               2  30.030769        0
#
# ...

# %%
df.sort_values("Age", ascending=False)
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 1251       6285   79       1          0               1  29.993441        1
# 226        5260   79       0          3               1  18.372529        0
# 697        5731   79       1          1               1  31.282971        0
# 1031       6065   79       1          0               0  18.307355        0
# 843        5877   79       0          1               1  34.770417        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 619        5653    5       1          0               2  25.455246        0
# 2348       7382    5       0          1               1  20.936782        0
# 1008       6042    5       1          0               1  17.190758        1
# 679        5713    5       0          2               1  26.850546        0
# 405        5439    5       0          3               2  21.866782        0
#
# ...

# %%
df.sort_values(["Age", "BMI"])
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 1008       6042    5       1          0               1  17.190758        1
# 814        5848    5       0          0               1  17.572297        0
# 1438       6472    5       0          0               1  17.651456        0
# 1579       6613    5       0          1               1  18.601088        1
# 1784       6818    5       1          0               0  19.462619        1
# ...         ...  ...     ...        ...             ...        ...      ...
# 71         5105   79       1          1               2  38.421666        0
# 1933       6967   79       0          0               0  38.578388        1
# 1611       6645   79       0          1               2  38.712137        1
# 865        5899   79       1          0               3  39.010001        0
# 1376       6410   79       0          0               0  39.666881        0
#
# ...

# %% [markdown]
# Avval age bo'yicha so'rtlab Agar bir hil agelilar bo'lsa keyin Body index bo'yicha teskari tartibda so'rtlayapti

# %%
df.sort_values(["Age", "BMI"], ascending=[True, False])
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 2211       7245    5       0          0               1  38.155312        1
# 2207       7241    5       1          0               2  37.839054        0
# 990        6024    5       1          3               1  36.251830        0
# 1826       6860    5       0          1               0  36.172342        0
# 2377       7411    5       1          1               2  35.479080        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 226        5260   79       0          3               1  18.372529        0
# 1031       6065   79       1          0               0  18.307355        0
# 1984       7018   79       1          3               0  17.867079        0
# 68         5102   79       0          0               3  17.786832        0
# 784        5818   79       1          3               2  15.325347        0
#
# ...

# %% [markdown]
# ### Bir nechta columnlarni chiqarish

# %%
df[['Age', 'Gender', 'Ethnicity']]
# Out:
#       Age  Gender  Ethnicity
# 0      63       0          1
# 1      26       1          2
# 2      57       0          2
# 3      40       1          2
# 4      61       0          0
# ...   ...     ...        ...
# 2387   43       1          0
# 2388   18       1          0
# 2389   54       0          3
# 2390   46       1          0
# 2391   26       1          0
#
# [2392 rows x 3 columns]

# %% [markdown]
# Bir nechta columnlarni o'zgaruvchiga tenglab qo'yish

# %%
columns = ['Age', 'Gender', 'Ethnicity']
df[columns]
# Out:
#       Age  Gender  Ethnicity
# 0      63       0          1
# 1      26       1          2
# 2      57       0          2
# 3      40       1          2
# 4      61       0          0
# ...   ...     ...        ...
# 2387   43       1          0
# 2388   18       1          0
# 2389   54       0          3
# 2390   46       1          0
# 2391   26       1          0
#
# [2392 rows x 3 columns]

# %% [markdown]
# Columns ustida turli holatlar

# %%
is_male = df['Gender'] == 0
is_asia = df['Ethnicity'] == 2

df[is_male & is_asia]
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 2          5036   57       0          2               1  18.395396        0
# 5          5039   21       0          2               0  21.812975        0
# 21         5055   72       0          2               1  33.550266        0
# 22         5056   53       0          2               1  37.923024        0
# 40         5074    7       0          2               2  16.343191        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2251       7285   27       0          2               1  33.115695        0
# 2319       7353   26       0          2               2  25.396059        0
# 2334       7368   75       0          2               2  30.437967        0
# 2356       7390    6       0          2               1  36.501742        0
# 2366       7400   35       0          2               0  22.154735        0
#
# ...

# %% [markdown]
# .isin() - method kelayotgan yosh tganlangan yoshlar ichida bo'lsa chiqaradi

# %%
is_58_or_59 = df['Age'].isin([58, 59])
df[is_58_or_59]
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 56         5090   58       0          0               1  15.641879        0
# 78         5112   58       1          0               1  18.503524        0
# 126        5160   58       0          0               3  39.101842        0
# 234        5268   58       0          0               2  23.356623        0
# 358        5392   58       0          0               1  34.636258        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2237       7271   58       0          1               1  26.459200        0
# 2327       7361   59       0          1               1  36.136556        0
# 2339       7373   59       1          0               2  35.551043        0
# 2360       7394   58       1          0               3  28.265492        0
# 2368       7402   58       0          0               1  33.382904        0
#
# ...

# %% [markdown]
# ### Yangi column qo'shish

# %% [markdown]
# !! Natija(amal) mantiqsiz bo'lishi mumkin. Chunki o'zim o'ylab topdim

# %%
df['Activity'] = df['PhysicalActivity'] - df['SleepQuality']
df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          5034   63       0          1               0  15.848744        0
# 1          5035   26       1          2               2  22.757042        0
# 2          5036   57       0          2               1  18.395396        0
# 3          5037   40       1          2               1  38.515278        0
# 4          5038   61       0          0               3  19.283802        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2387       7421   43       1          0               2  29.059613        0
# 2388       7422   18       1          0               1  20.740850        0
# 2389       7423   54       0          3               2  37.079560        0
# 2390       7424   46       1          0               2  23.444712        0
# 2391       7425   26       1          0               0  28.123021        1
#
# ...

# %% [markdown]
# ### Multiple Manipulations

# %%
physical_activity_until_5 = df[df['PhysicalActivity'] <= 5]
physical_activity_until_5_age = physical_activity_until_5.sort_values('Age', ascending=False)
physical_activity_until_5_age[['PatientID', 'Age', 'PhysicalActivity']]
# Out:
#       PatientID  Age  PhysicalActivity
# 591        5625   79          2.106627
# 1251       6285   79          2.812983
# 1933       6967   79          3.261688
# 2176       7210   79          1.150078
# 368        5402   79          4.102267
# ...         ...  ...               ...
# 2377       7411    5          4.571440
# 1438       6472    5          4.372488
# 1579       6613    5          2.182973
# 703        5737    5          2.048262
# 1608       6642    5          4.060767
#
# [1191 rows x 3 columns]
