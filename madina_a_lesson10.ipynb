# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("index 2.csv")
df
# Out:
#            date                 datetime cash_type                 card  \
# 0    2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1    2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2    2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3    2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4    2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ..          ...                      ...       ...                  ...
# 891  2024-06-29  2024-06-29 21:27:22.449      card  ANON-0000-0000-0009
# 892  2024-06-30  2024-06-30 10:28:09.842      card  ANON-0000-0000-0336
# 893  2024-06-30  2024-06-30 13:05:50.620      card  ANON-0000-0000-0337
# 894  2024-06-30  2024-06-30 16:54:41.679      card  ANON-0000-0000-0009
# 895  2024-06-30  2024-06-30 21:04:09.746      card  ANON-0000-0000-0097
#
#      money          coffee_name
# 0    38.70                Latte
# 1    38.70        Hot Chocolate
# ...

# %%
df.shape
# Out:
# (896, 6)

# %% [markdown]
# ### Problem: Plot the count of each coffee type sold.

# %%
sns.countplot(data = df, x="coffee_name", hue="coffee_name")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Hulosa: Eng ko'p sotiladigan cofe type bu Americano with milk(200), Latte(tahminan178). Eng kam sotiladigani esa Cocoa va Exspresso

# %% [markdown]
# ### Problem: Compare the average amount of money spent for each coffee type.

# %%
spend_money = df.groupby("coffee_name")["money"].mean()
spend_money
# Out:
# coffee_name
# Americano              28.469323
# Americano with Milk    33.192808
# Cappuccino             38.131098
# Cocoa                  38.294615
# Cortado                28.503529
# Espresso               23.638286
# Hot Chocolate          38.372381
# Latte                  38.243957
# Name: money, dtype: float64

# %%
sns.barplot(data=df, x="coffee_name", y="money", hue="coffee_name", estimator="mean")

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Boya ko'rgan count plotda Cocoa eng kam natijani ko'rsatgan bo'lsa ham eng ko'p sarflanadigan pul aynan Cocoa ga tegishli. Ammo Espressoga sarflangan pul halli ham eng kam miqdroda.

# %% [markdown]
# ### Problem: Visualize the distribution of money spent for each coffee type.

# %%
sns.set= ( "whitegrid")
sns.boxplot(data=df, y="coffee_name", x="money", hue="coffee_name")
# Out:
# <Axes: xlabel='money', ylabel='coffee_name'>

# %%
df["coffee_name"].value_counts()
# Out:
# coffee_name
# Americano with Milk    203
# Latte                  187
# Cappuccino             164
# Americano              133
# Cortado                 85
# Hot Chocolate           63
# Espresso                35
# Cocoa                   26
# Name: count, dtype: int64

# %% [markdown]
# #### Bu box plot yuqoridagi bar plot bilan bir hil natija ko'rsatmmoqda

# %% [markdown]
# ### Problem: Visualize the distribution of money spent for each coffee type with more detail.

# %%
sns.violinplot(data = df, y="coffee_name", x="money", hue = "coffee_name")
# Out:
# <Axes: xlabel='money', ylabel='coffee_name'>

# %% [markdown]
# #### Violent plot bizga ko'proq ma'lumotlani ko'rsata oladi. Misol uchun Hot chocolate typeiga to'langan pul hammasinikidan ham ko'proq ekan Buni o'rtadagi oq chiziqdan ko'rishimiz mumkin. Cappuccino va Latte uchun asosiy sale esa 37.5.

# %% [markdown]
# ### Problem: Display all individual transactions of money spent for each coffee type.

# %%
sns.stripplot(data=df, y = "coffee_name", x="money", hue="coffee_name")
# Out:
# <Axes: xlabel='money', ylabel='coffee_name'>

# %% [markdown]
# #### Problem: Display all individual transactions of money spent for each coffee type while avoiding overlap.

# %%
sns.swarmplot(data=df, y = "coffee_name", x="money", hue="coffee_name")
# Out:
# /Users/applebro/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 89.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/applebro/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 74.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/applebro/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 88.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/applebro/Library/Python/3.9/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 92.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# #### ma'lum bir coffe uchun sarflangan pullar typei ko'p bo'lmaganligi sababli stripplot va swarmplotlar chiroyli chiqmadi.
