# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('planes.csv')
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0      Jet Airways       9/06/2019     Delhi      Cochin
# 1           IndiGo      12/05/2019   Kolkata    Banglore
# 2           IndiGo      01/03/2019  Banglore   New Delhi
# 3         SpiceJet      24/06/2019   Kolkata    Banglore
# 4      Jet Airways      12/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10655     Air Asia       9/04/2019   Kolkata    Banglore
# 10656    Air India      27/04/2019   Kolkata    Banglore
# 10657  Jet Airways      27/04/2019  Banglore       Delhi
# 10658      Vistara      01/03/2019  Banglore   New Delhi
# 10659    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 1            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10660 entries, 0 to 10659
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10233 non-null  object
#  1   Date_of_Journey  10338 non-null  object
#  2   Source           10473 non-null  object
#  3   Destination      10313 non-null  object
#  4   Route            10404 non-null  object
#  5   Dep_Time         10400 non-null  object
#  6   Arrival_Time     10466 non-null  object
#  7   Duration         10446 non-null  object
#  8   Total_Stops      10448 non-null  object
#  9   Additional_Info  10071 non-null  object
#  10  Price            10044 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 916.2+ KB

# %% [markdown]
# #### Hech qaysi ustun to'liq emaas ekan.va bizdagi asosiy data type object

# %%
df = pd.read_csv('planes.csv')
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0      Jet Airways       9/06/2019     Delhi      Cochin
# 1           IndiGo      12/05/2019   Kolkata    Banglore
# 2           IndiGo      01/03/2019  Banglore   New Delhi
# 3         SpiceJet      24/06/2019   Kolkata    Banglore
# 4      Jet Airways      12/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10655     Air Asia       9/04/2019   Kolkata    Banglore
# 10656    Air India      27/04/2019   Kolkata    Banglore
# 10657  Jet Airways      27/04/2019  Banglore       Delhi
# 10658      Vistara      01/03/2019  Banglore   New Delhi
# 10659    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 1            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# ...

# %%
df['Destination'].value_counts()
# Out:
# Destination
# Cochin       4391
# Banglore     2773
# Delhi        1219
# New Delhi     888
# Hyderabad     673
# Kolkata       369
# Name: count, dtype: int64

# %%
df.select_dtypes('object')
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0      Jet Airways       9/06/2019     Delhi      Cochin
# 1           IndiGo      12/05/2019   Kolkata    Banglore
# 2           IndiGo      01/03/2019  Banglore   New Delhi
# 3         SpiceJet      24/06/2019   Kolkata    Banglore
# 4      Jet Airways      12/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10655     Air Asia       9/04/2019   Kolkata    Banglore
# 10656    Air India      27/04/2019   Kolkata    Banglore
# 10657  Jet Airways      27/04/2019  Banglore       Delhi
# 10658      Vistara      01/03/2019  Banglore   New Delhi
# 10659    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 1            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# ...

# %%
sns.histplot(data=df, x='Destination', hue= 'Destination')
# Out:
# <Axes: xlabel='Destination', ylabel='Count'>

# %% [markdown]
# #### Eng ko'p uchush Cochinga tomonga bo'lgan. Eng kami esa Kolkataga

# %%
df.value_counts('Airline')
# Out:
# Airline
# Jet Airways          3685
# IndiGo               1981
# Air India            1686
# Multiple carriers    1148
# SpiceJet              787
# Vistara               455
# Air Asia              309
# GoAir                 182
# Name: count, dtype: int64

# %%
sns.histplot(data=df, x='Airline', hue= 'Airline')
# Out:
# <Axes: xlabel='Airline', ylabel='Count'>

# %% [markdown]
# #### Eng ko'p uchishlar Jet Airways havo yo'llarida amalga oshirilar ekan, eng kami esa GoAir da

# %%
df.groupby('Airline')['Price'].agg(['count','mean', 'median', 'min', 'max'])
# Out:
#                    count          mean   median     min      max
# Airline
# Air Asia             295   5629.657627   5192.0  3383.0  13474.0
# Air India           1602   9593.015605   9443.0  2050.0  31945.0
# GoAir                176   5914.477273   5135.0  3398.0  22794.0
# IndiGo              1865   5684.994638   5013.0  2227.0  19685.0
# Jet Airways         3487  11605.228850  11467.0  1840.0  54826.0
# Multiple carriers   1073  10867.189189   9871.0  5797.0  36983.0
# SpiceJet             751   4290.035952   3873.0  1759.0  23267.0
# Vistara              433   7831.260970   8028.0  3687.0  21730.0

# %%
sns.boxplot(data=df, x='Price')
plt.show()

# %%
sns.boxplot(data = df, x='Price', y='Destination', hue='Destination')
# Out:
# <Axes: xlabel='Price', ylabel='Destination'>

# %% [markdown]
# Eng ko'p manzil Cochin bo'lgan bo'lsa ham eng qimmat bilet New Delhi da

# %%
pd.crosstab(df['Source'], df['Destination'],
            values=df['Price'], aggfunc='median')
# Out:
# Destination  Banglore   Cochin   Delhi  Hyderabad  Kolkata  New Delhi
# Source
# Banglore          NaN      NaN  4823.0        NaN      NaN    10976.5
# Chennai           NaN      NaN     NaN        NaN   3850.0        NaN
# Delhi             NaN  10262.0     NaN        NaN      NaN        NaN
# Kolkata        9345.0      NaN     NaN        NaN      NaN        NaN
# Mumbai            NaN      NaN     NaN     3342.0      NaN        NaN

# %%
corr = pd.crosstab(df['Airline'], df['Destination'],
            values=df['Destination'], aggfunc='count')
# Out:
# Destination        Banglore  Cochin  Delhi  Hyderabad  Kolkata  New Delhi
# Airline
# Air Asia              143.0    75.0   67.0        NaN      NaN       17.0
# Air India             474.0   695.0  115.0      126.0     24.0      195.0
# GoAir                  20.0    72.0   61.0        NaN      NaN       22.0
# IndiGo                416.0   657.0  339.0      181.0    173.0      146.0
# Jet Airways          1155.0  1474.0  345.0      207.0      NaN      388.0
# Multiple carriers       NaN  1115.0    NaN        NaN      NaN        NaN
# SpiceJet              282.0    80.0  127.0      116.0    118.0       38.0
# Vistara               166.0    41.0  116.0       22.0     42.0       47.0

# %%
df['Duration_minutes'] = pd.to_timedelta(df['Duration']).dt.total_seconds() / 60
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0      Jet Airways       9/06/2019     Delhi      Cochin
# 1           IndiGo      12/05/2019   Kolkata    Banglore
# 2           IndiGo      01/03/2019  Banglore   New Delhi
# 3         SpiceJet      24/06/2019   Kolkata    Banglore
# 4      Jet Airways      12/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10655     Air Asia       9/04/2019   Kolkata    Banglore
# 10656    Air India      27/04/2019   Kolkata    Banglore
# 10657  Jet Airways      27/04/2019  Banglore       Delhi
# 10658      Vistara      01/03/2019  Banglore   New Delhi
# 10659    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 1            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# ...

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()

# %%
df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5503
# non-stop    3411
# 2 stops     1488
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
stops_mapping = {'non-stop': 0,
                 '1 stop': 1,
                 '2 stops': 2,
                 '3 stops': 3, 
                 '4 stops': 4}

df['Total_Stops_Mapped'] = df['Total_Stops'].replace(stops_mapping)
df
# Out:
# /var/folders/66/x0152m9s4fxg2fz8tfrrqlc80000gp/T/ipykernel_92241/1724912774.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Total_Stops_Mapped'] = df['Total_Stops'].replace(stops_mapping)
#            Airline Date_of_Journey    Source Destination  \
# 0      Jet Airways       9/06/2019     Delhi      Cochin
# 1           IndiGo      12/05/2019   Kolkata    Banglore
# 2           IndiGo      01/03/2019  Banglore   New Delhi
# 3         SpiceJet      24/06/2019   Kolkata    Banglore
# 4      Jet Airways      12/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10655     Air Asia       9/04/2019   Kolkata    Banglore
# 10656    Air India      27/04/2019   Kolkata    Banglore
# ...

# %% [markdown]
# #### Total_stopsni ham numeric qilib oldik

# %%
df.select_dtypes('float')
# Out:
#          Price  Duration_minutes  Total_Stops_Mapped
# 0      13882.0            1140.0                 2.0
# 1       6218.0             325.0                 1.0
# 2      13302.0             285.0                 1.0
# 3       3873.0             145.0                 0.0
# 4      11087.0             930.0                 1.0
# ...        ...               ...                 ...
# 10655   4107.0             150.0                 0.0
# 10656   4145.0             155.0                 0.0
# 10657   7229.0             180.0                 0.0
# 10658  12648.0             160.0                 0.0
# 10659  11753.0             500.0                 2.0
#
# [10660 rows x 3 columns]
