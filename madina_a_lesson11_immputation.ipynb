# %%
import pandas as pd
#import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('example.csv')
df
# Out:
#        Unnamed: 0  Safety    yacEPA  Drive  FieldGoalDistance    airEPA  \
# 0          244485       0  1.240299     18                NaN -0.588101
# 1          115340       0       NaN     22                NaN       NaN
# 2           68357       0       NaN      8                NaN       NaN
# 3          368377       0  1.075660     24                NaN  0.402080
# 4          384684       0       NaN     11                NaN       NaN
# ...           ...     ...       ...    ...                ...       ...
# 40764       79438       0       NaN      3                NaN       NaN
# 40765      398233       0       NaN      9                NaN       NaN
# 40766      396466       0       NaN      8                NaN       NaN
# 40767      333861       0  0.025040     14                NaN  0.280049
# 40768      247608       0 -2.441755      6                NaN  1.692283
#
#        Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0        Safety        yacEPA         Drive  \
# count   40769.000000  40769.000000  15867.000000  40769.000000
# mean   202916.414359      0.000294     -0.396137     12.287817
# std    117725.700085      0.017154      1.998663      7.169334
# min        47.000000      0.000000    -14.000000      1.000000
# 25%    101844.000000      0.000000     -0.961252      6.000000
# 50%    201785.000000      0.000000      0.000000     12.000000
# 75%    304505.000000      0.000000      0.484938     18.000000
# max    407658.000000      1.000000      8.390143     34.000000
#
#        FieldGoalDistance        airEPA  Field_Goal_Prob  Penalty.Yards  \
# count         902.000000  15875.000000     40748.000000   40769.000000
# mean           37.487805      0.522389         0.243680       0.607349
# std            10.049785      1.399720         0.159400       2.585225
# min            18.000000     -5.930319         0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40769 entries, 0 to 40768
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   40769 non-null  int64
#  1   Safety                       40769 non-null  int64
#  2   yacEPA                       15867 non-null  float64
#  3   Drive                        40769 non-null  int64
#  4   FieldGoalDistance            902 non-null    float64
#  5   airEPA                       15875 non-null  float64
#  6   Field_Goal_Prob              40748 non-null  float64
#  7   posteam                      38219 non-null  object
#  8   Penalty.Yards                40769 non-null  int64
#  9   FieldGoalResult              908 non-null    object
#  10  DefTeamScore                 38019 non-null  float64
#  11  Tackler2                     4943 non-null   object
#  12  Away_WP_pre                  38223 non-null  float64
# ...

# %%
df.drop(columns='TwoPointConv')
# Out:
#        Unnamed: 0  Safety    yacEPA  Drive  FieldGoalDistance    airEPA  \
# 0          244485       0  1.240299     18                NaN -0.588101
# 1          115340       0       NaN     22                NaN       NaN
# 2           68357       0       NaN      8                NaN       NaN
# 3          368377       0  1.075660     24                NaN  0.402080
# 4          384684       0       NaN     11                NaN       NaN
# ...           ...     ...       ...    ...                ...       ...
# 40764       79438       0       NaN      3                NaN       NaN
# 40765      398233       0       NaN      9                NaN       NaN
# 40766      396466       0       NaN      8                NaN       NaN
# 40767      333861       0  0.025040     14                NaN  0.280049
# 40768      247608       0 -2.441755      6                NaN  1.692283
#
#        Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  RunGap  \
# ...

# %% [markdown]
# #### Two pointy Conv ustunida 40769 ta qatordan faqat 53 tasida ma'lumot bo'lib qolganlari Null bo'lgani uchun o'sha ustun tushirib yuborildi

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                         0
# Safety                             0
# yacEPA                         24902
# Drive                              0
# FieldGoalDistance              39867
# airEPA                         24894
# Field_Goal_Prob                   21
# posteam                         2550
# Penalty.Yards                      0
# FieldGoalResult                39861
# DefTeamScore                    2750
# Tackler2                       35826
# Away_WP_pre                     2546
# Timeout_Indicator                  0
# ydsnet                             0
# TimeSecs                          27
# Passer                         24073
# Touchdown                          0
# TwoPointConv                   40716
# PassOutcome                    24018
# PlayTimeDiff                      43
# RushAttempt                        0
# Accepted.Penalty                   0
# qtr                                0
# AwayTimeouts_Remaining_Post        0
# ...

# %%
df.shape
# Out:
# (40769, 32)

# %%
df.dropna(how='any').shape
# Out:
# (0, 32)

# %% [markdown]
# #### Demak jadvalimizda umuman NaN yoki Null qatnashmagan qator mavjud emas

# %%
df.groupby('posteam').count()
# Out:
#          Unnamed: 0  Safety  yacEPA  Drive  FieldGoalDistance  airEPA  \
# posteam
# ARI            1208    1208     530   1208                 26     530
# ATL            1167    1167     492   1167                 33     493
# BAL            1218    1218     510   1218                 37     511
# BUF            1186    1186     477   1186                 29     476
# CAR            1128    1128     443   1128                 19     446
# CHI            1188    1188     465   1188                 18     465
# CIN            1189    1189     482   1189                 32     483
# CLE            1117    1117     480   1117                 21     480
# DAL            1192    1192     483   1192                 37     484
# DEN            1284    1284     544   1284                 33     544
# DET            1243    1243     590   1243                 32     591
# GB             1198    1198     524   1198                 26     524
# ...

# %%
df['posteam_no_NaN'] = df['posteam'].fillna(value="None given")
df
# Out:
#        Unnamed: 0  Safety    yacEPA  Drive  FieldGoalDistance    airEPA  \
# 0          244485       0  1.240299     18                NaN -0.588101
# 1          115340       0       NaN     22                NaN       NaN
# 2           68357       0       NaN      8                NaN       NaN
# 3          368377       0  1.075660     24                NaN  0.402080
# 4          384684       0       NaN     11                NaN       NaN
# ...           ...     ...       ...    ...                ...       ...
# 40764       79438       0       NaN      3                NaN       NaN
# 40765      398233       0       NaN      9                NaN       NaN
# 40766      396466       0       NaN      8                NaN       NaN
# 40767      333861       0  0.025040     14                NaN  0.280049
# 40768      247608       0 -2.441755      6                NaN  1.692283
#
#        Field_Goal_Prob posteam  Penalty.Yards FieldGoalResult  ...  qtr  \
# ...

# %% [markdown]
# #### posteam ustunidagi NaN larni o'rni ustun type i string bo'lgani ucun None given bilan to'ldirib chiqildi

# %%
key = df['yacEPA']
print(key.mean())
print(key.median())
# Out:
# -0.39613653499874507
# 0.0

# %%
key = df['Field_Goal_Prob']
print(key.mean())
print(key.median())
# Out:
# 0.24367961032922636
# 0.2306319714387671

# %%
df['new_Field_Goal_Prob'] = key.fillna(key).mean()

# %%
print(df['new_Field_Goal_Prob'].mean())
print(df['new_Field_Goal_Prob'].median())
# Out:
# 0.24367961032922641
# 0.24367961032922636

# %% [markdown]
# #### Field_Goal_Prob ustunidagi Nan lar o'rniga o'rtachasi qo'yilgan holda 'new_Field_Goal_Prob' ustuniga ko'chirildi. mean va medianlar deyarli o'zgarmagan

# %%
key = df['DefTeamScore']
print(key.mean())
print(key.median())
# Out:
# 11.366316841579211
# 10.0

# %%
df['new_DefTeamScore'] = key.fillna(key).mean()

# %%
print(df['new_DefTeamScore'].mean())
print(df['new_DefTeamScore'].median())
# Out:
# 11.366316841579211
# 11.366316841579211

# %% [markdown]
# #### Deyarli mean max o'zgarmadi
